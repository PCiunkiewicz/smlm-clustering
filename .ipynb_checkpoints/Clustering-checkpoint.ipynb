# %%
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.model_selection import ParameterSampler
import hdbscan

from tqdm import trange
from scipy.spatial.distance import cdist
from scipy.stats import randint
import clustering

# %%
from IPython.core.interactiveshell import InteractiveShell
from importlib import reload
reload(clustering)
from clustering import *

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# %matplotlib inline
InteractiveShell.ast_node_interactivity = 'all'
sns.set()
sns.set(rc={'figure.figsize':(12,8)})
# Out:
# <module 'clustering' from 'C:\\Users\\LCI_user\\Documents\\GitHub\\LCI-Clustering\\clustering.py'>

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('Diskovery_Cell1_ThunderSTORM.csv')
df.head()
df = df.sort_values(by=['intensity [photon]'])
# Out:
#     id  frame       x [nm]        y [nm]  sigma [nm]  intensity [photon]  \
# 0  1.0    1.0  2474.998618   6736.088180  195.815722         1841.965445
# 1  2.0    1.0  4356.136836  14133.322371  145.009192         5599.702004
# 2  3.0    1.0  4542.775300   9091.265025  121.313419          221.442108
# 3  4.0    1.0  5977.444344   7594.973438  137.276419          155.518749
# 4  5.0    1.0  6079.459555  11231.168432  137.261612         2693.631410
#
#    offset [photon]  bkgstd [photon]  uncertainty [nm]
# 0        80.087915        10.501425          9.781846
# 1        82.962749        24.851702          4.184589
# 2        39.507939         4.162599         15.045367
# 3        39.499220         4.681645         24.730111
# 4        59.415820        11.278048          4.647010

# %% [markdown]
# ## Displaying Raw Data

# %%
img = plt.scatter(df['x [nm]'],
                  df['y [nm]'],
                  c=df['intensity [photon]'],
                  s=5, cmap='RdYlGn',alpha=0.2)
_ = plt.colorbar(img)

# %% [markdown]
# ## Applying DBSCAN

# %%
# %matplotlib widget
sns.set(rc={'figure.figsize':(6,6)})

# %%
XY = np.column_stack((df['x [nm]'],df['y [nm]']))[::10]

db = DBSCAN(eps=147, min_samples=73, n_jobs=6)
custom_silhouette(db,XY,cv=2)
dbscan_verbose(db, XY, plot=True)
# Out:
# (0.6951561008242889, 0.002424250715831411)
# Estimated number of clusters: 96
# Estimated number of noise points: 3722
# Total number of points: 89939
# FigureCanvasNbAgg()

# %% [markdown]
# ## RipleyK test

# %%
from astropy.stats import RipleysKEstimator
labels = db.labels_
z = XY[labels==0] / 1000

Kest = RipleysKEstimator(area=4, x_max=6.4, y_max=7.7, x_min=5, y_min=6.6)

r = np.linspace(0, 2, 100)
plt.plot(r, Kest.poisson(r), color='green', ls=':', label=r'$K_{pois}$')
plt.plot(r, Kest(data=z, radii=r, mode='none'), color='red', ls='--',
         label=r'$K_{un}$')
plt.plot(r, Kest(data=z, radii=r, mode='translation'), color='black',
         label=r'$K_{trans}$')
# plt.plot(r, Kest(data=z, radii=r, mode='ohser'), color='blue', ls='-.',
#          label=r'$K_{ohser}$')
# plt.plot(r, Kest(data=z, radii=r, mode='var-width'), color='green',
#          label=r'$K_{var-width}$')
# plt.plot(r, Kest(data=z, radii=r, mode='ripley'), color='yellow',
#          label=r'$K_{ripley}$')

plt.legend()

# %%
dbscan_verbose(db, XY, plot=True,n=[0])

# %% [markdown]
# ## Sparse neighbor distance matrix
#
# Try this again next time and throw into DBSCAN to see if performance improves

# %%
from sklearn.neighbors import radius_neighbors_graph

coords = np.column_stack((df['x [nm]'],df['y [nm]']))[::50]

test = radius_neighbors_graph(X=coords, radius=200, mode='distance')
test.todense()
# Out:
# 384208785.9220097

# %%
dbscan = DBSCAN(n_jobs=6,metric='precomputed',eps=1000,min_samples=5)

param_dist = {"eps": randint(120, 200),
              "min_samples": randint(30, 300)}

def custom_silhouette2(dbscan,X):
    db = dbscan.fit(X)
    labels = db.labels_
    score = silhouette_score(X.todense().T, labels, metric="precomputed")
    
    return score

custom_silhouette2(dbscan,test)
# Out:
# -0.9919946631087392

# %%
dbscan_verbose(dbscan, coords, plot=True)
# Out:
# Estimated number of clusters: 97
# Estimated number of noise points: 436
# Total number of points: 17988

# %% [markdown]
# ## Hyper Parameter Search

# %%
dbscan = DBSCAN(n_jobs=6)

param_dist = {"eps": randint(120, 200),
              "min_samples": randint(30, 300)}
    
results = random_search_custom(dbscan,param_dist,XY,n=200,cv=3)
results

# %% [markdown]
# ## HDBSCAN Test

# %%
XY = np.column_stack((df['x [nm]'],df['y [nm]']))[::5]
hdb = hdbscan.HDBSCAN(core_dist_n_jobs=6,gen_min_span_tree=True)

param_dist = {"min_cluster_size": randint(200, 1000),
              "min_samples": randint(500, 1000,5),
              "alpha": np.linspace(0.1,2,100)}
    
results = random_search_custom2(hdb,param_dist,XY,n=10)
results.head(10)
# Out:
#   0%|                                                   | 0/10 [00:00<?, ?it/s]
#
#
#  10%|████▏                                     | 1/10 [01:57<17:38, 117.65s/it]
#
#
#  20%|████████▍                                 | 2/10 [03:50<15:29, 116.22s/it]
#
#
#  30%|████████████▌                             | 3/10 [05:53<13:47, 118.17s/it]
#
#
#  40%|████████████████▊                         | 4/10 [07:59<12:03, 120.51s/it]
#
#
#  50%|█████████████████████                     | 5/10 [10:01<10:05, 121.16s/it]
#
#
#  60%|█████████████████████████▏                | 6/10 [12:06<08:09, 122.29s/it]
#
#
#  70%|█████████████████████████████▍            | 7/10 [14:05<06:03, 121.12s/it]
#
#
#  80%|█████████████████████████████████▌        | 8/10 [16:10<04:05, 122.51s/it]
#
#
#  90%|█████████████████████████████████████▊    | 9/10 [18:14<02:02, 122.67s/it]
#
#
# 100%|█████████████████████████████████████████| 10/10 [20:13<00:00, 121.59s/it]
#       score     alpha  min_cluster_size  min_samples
# 3  0.601635  0.656566               645          876
# 5  0.601485  1.520202               542          814
# 7  0.588290  0.618182               887          820
# 8  0.555914  0.982828               830          496
# 9  0.537650  0.848485               751          498
# 6  0.536827  1.424242               624          430
# 0  0.447508  0.195960               347          217
# 2  0.425176  0.790909               979          192
# 4  0.255781  1.577778               976          108
# 1  0.249148  1.750505               393           70

# %%
XY = np.column_stack((df['x [nm]'],df['y [nm]']))[::5]
hdb = hdbscan.HDBSCAN(core_dist_n_jobs=6,min_cluster_size=645,min_samples=876,gen_min_span_tree=True)
_ = hdb.fit(XY)

# custom_silhouette(hdb,XY,cv=1)
# hdb.relative_validity_
# hdbscan.validity.validity_index(XY,hdb.labels_)

# %%
dbscan_verbose(hdb, XY, plot=True)
# Out:
# Estimated number of clusters: 64
# Estimated number of noise points: 10357
# Total number of points: 179878

# %%
clust = hdb.labels_ == 10
prob = hdb.probabilities_[clust]

fig,axes = plt.subplots(1,2,figsize=[14,6])

_ = sns.distplot(prob, norm_hist=True,bins=np.linspace(0.01,1,100),ax=axes[0])
_ = axes[0].set(xlim=(0,1))

p = 0.1
_ = sns.scatterplot(*XY[clust][prob<=p].T,alpha=0.5,color='r',ax=axes[1],label=f'$p\\leq{p}$')
_ = sns.scatterplot(*XY[clust][prob>p].T,alpha=0.5,color='b',ax=axes[1],label=f'$p>{p}$')

# %%
dbscan_verbose(hdb, XY, plot=True,p=0.0,silent=True)
