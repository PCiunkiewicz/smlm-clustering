# %%
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import metrics
from tqdm import trange
from scipy.spatial.distance import cdist
import clustering

# %%
from IPython.core.interactiveshell import InteractiveShell
from importlib import reload
reload(clustering)
from clustering import *

InteractiveShell.ast_node_interactivity = 'all'
sns.set()
sns.set(rc={'figure.figsize':(12,8)})

# %%
df = pd.read_csv('Diskovery_Cell1_ThunderSTORM.csv')
df.head()
# Out:
#     id  frame       x [nm]        y [nm]  sigma [nm]  intensity [photon]  \
# 0  1.0    1.0  2474.998618   6736.088180  195.815722         1841.965445
# 1  2.0    1.0  4356.136836  14133.322371  145.009192         5599.702004
# 2  3.0    1.0  4542.775300   9091.265025  121.313419          221.442108
# 3  4.0    1.0  5977.444344   7594.973438  137.276419          155.518749
# 4  5.0    1.0  6079.459555  11231.168432  137.261612         2693.631410
#
#    offset [photon]  bkgstd [photon]  uncertainty [nm]
# 0        80.087915        10.501425          9.781846
# 1        82.962749        24.851702          4.184589
# 2        39.507939         4.162599         15.045367
# 3        39.499220         4.681645         24.730111
# 4        59.415820        11.278048          4.647010

# %%
df = df.sort_values(by=['intensity [photon]'])
skip = 1

img = plt.scatter(df[::skip]['x [nm]'],
                  df[::skip]['y [nm]'],
                  c=df[::skip]['intensity [photon]'],
                  s=5, cmap='RdYlGn',alpha=0.2)
_ = plt.colorbar(img)

# %%
XY = np.column_stack((df['x [nm]'],df['y [nm]']))[::10]

samples = np.random.choice(np.arange(len(XY)),10000)
xy = XY[samples]
xydist = cdist(xy,xy)

# %%
db = DBSCAN(eps=100, min_samples=20, n_jobs=6).fit(XY)
labels = db.labels_[samples]
metrics.silhouette_score(xydist, labels, metric="precomputed")
dbscan_verbose(db, XY, plot=True)
# Out:
# 0.6735762056436212
# Estimated number of clusters: 115
# Estimated number of noise points: 3547
# Total number of points: 89939

# %% [markdown]
# To do:
#
# hyperparameter search using silhouette score
#
#     build score function
